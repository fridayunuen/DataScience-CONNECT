# %%
import os
import pandas as pd

path = os.getcwd()
path_input = path.replace("code", "input")
path_output = r'S:\OMNI\HerramientasCode\MappingDiario'
path_contrasenas = r'C:\Users\fcolin\Desktop\input\CredencialesConnect.json'
path_sap_reporte = r'S:\OMNI\HerramientasCode\MappingDiario\input'

# %%
# DRIVE ----------------------------------------------------------------------------------------------
Drive = pd.read_csv(r"S:\OMNI\HerramientasCode\MappingDiario\Mapping.csv")
Drive.sort_values(by=['creation_date'], ascending=False, inplace=True)
drive = Drive[["sku", "path"]]
drive = drive.drop_duplicates(subset="sku", keep="first")
drive.reset_index(drop=True, inplace=True)
drive["sku"] = drive["sku"].astype(str)
drive
# Out:
#               sku                        path
# 0      2215955070  \CONNECT\TODOS_LOS_TAMANOS
# 1      2218289070  \CONNECT\TODOS_LOS_TAMANOS
# 2      2300058012  \CONNECT\TODOS_LOS_TAMANOS
# 3      2301722098  \CONNECT\TODOS_LOS_TAMANOS
# 4      2301721030  \CONNECT\TODOS_LOS_TAMANOS
# ...           ...                         ...
# 64208  1700373100                 \Accesorios
# 64209  1609239100                 \Accesorios
# 64210  1606006100                 \Accesorios
# 64211  1602207100                 \Accesorios
# 64212  1508029100                 \Accesorios
#
# [64213 rows x 2 columns]

# %%
# Producto dado de alta en SAP ------------------------------------------------
ProductosSAP = pd.read_csv(path_sap_reporte + "\SAP.csv", sep=";")
ProductosSAP
# Out:
#             INSERT_UPDATE Product code[unique=true]  \
# 0      ApparelStyleVariantProduct       1206956_070
# 1      ApparelStyleVariantProduct       1215560_051
# 2      ApparelStyleVariantProduct       1311919_060
# 3       ApparelSizeVariantProduct    1502602_034203
# 4       ApparelSizeVariantProduct    1502602_034204
# ...                           ...               ...
# 87458   ApparelSizeVariantProduct    2301014_038000
# 87459  ApparelStyleVariantProduct       2301054_045
# 87460   ApparelSizeVariantProduct    2301054_045000
# 87461  ApparelStyleVariantProduct       2301110_005
# 87462   ApparelSizeVariantProduct    2301110_005000
#
#                    name[lang=es] picture(code)[collection-delimiter=|]  \
# 0          Máscara pestañas base               /1200Wx1200H/1206956070
# 1           Perfume Only For You          /izq-/1200Wx1200H/1215560051
# 2            Perfume Sunset Love               /1200Wx1200H/1311919060
# 3      Flip flop textura correas          /der-/1200Wx1200H/1502602034
# 4      Flip flop textura correas          /der-/1200Wx1200H/1502602034
# ...                          ...                                   ...
# 87458         Esmalte metálico               /2/1200Wx1200H/2301014038
# 87459          Esmalte glitter               /2/1200Wx1200H/2301054045
# 87460          Esmalte glitter               /1/1200Wx1200H/2301054045
# 87461         Esmalte nacarado               /2/1200Wx1200H/2301110005
# 87462         Esmalte nacarado               /2/1200Wx1200H/2301110005
#
#       thumbnail(code)[collection-delimiter=|]  \
# 0                         /96Wx96H/1206956070
# 1                    /izq-/96Wx96H/1215560051
# 2                         /96Wx96H/1311919060
# 3                    /der-/96Wx96H/1502602034
# 4                    /der-/96Wx96H/1502602034
# ...                                       ...
# 87458                   /2/96Wx96H/2301014038
# 87459                   /2/96Wx96H/2301054045
# 87460                   /1/96Wx96H/2301054045
# 87461                   /2/96Wx96H/2301110005
# 87462                   /2/96Wx96H/2301110005
#
#       detail(code)[collection-delimiter=|]  \
# 0                    /300Wx300H/1206956070
# 1               /izq-/300Wx300H/1215560051
# 2                    /300Wx300H/1311919060
# 3               /der-/300Wx300H/1502602034
# 4               /der-/300Wx300H/1502602034
# ...                                    ...
# 87458              /2/300Wx300H/2301014038
# 87459              /2/300Wx300H/2301054045
# 87460              /1/300Wx300H/2301054045
# 87461              /2/300Wx300H/2301110005
# 87462              /2/300Wx300H/2301110005
#
#                     normal(code)[collection-delimiter=|]  \
# 0                /30Wx30H/1206956070|/65Wx65H/1206956070
# 1      /izq-/30Wx30H/1215560051|/izq-/65Wx65H/1215560051
# 2                /30Wx30H/1311919060|/65Wx65H/1311919060
# 3      /der-/30Wx30H/1502602034|/der-/65Wx65H/1502602034
# 4      /der-/30Wx30H/1502602034|/der-/65Wx65H/1502602034
# ...                                                  ...
# 87458                              /2/65Wx65H/2301014038
# 87459                              /2/65Wx65H/2301054045
# 87460                              /1/65Wx65H/2301054045
# 87461                              /2/65Wx65H/2301110005
# 87462                              /2/65Wx65H/2301110005
#
#       others(code)[collection-delimiter=|]  \
# 0                    /515Wx515H/1206956070
# 1               /izq-/515Wx515H/1215560051
# 2                    /515Wx515H/1311919060
# 3               /der-/515Wx515H/1502602034
# 4               /der-/515Wx515H/1502602034
# ...                                    ...
# 87458              /2/515Wx515H/2301014038
# 87459              /2/515Wx515H/2301054045
# 87460              /1/515Wx515H/2301054045
# 87461              /2/515Wx515H/2301110005
# 87462              /2/515Wx515H/2301110005
#
#       thumbnails(code)[collection-delimiter=|]  \
# 0                          /30Wx30H/1206956070
# 1                     /izq-/30Wx30H/1215560051
# 2                          /30Wx30H/1311919060
# 3                     /der-/30Wx30H/1502602034
# 4                     /der-/30Wx30H/1502602034
# ...                                        ...
# 87458                    /2/30Wx30H/2301014038
# 87459                    /2/30Wx30H/2301054045
# 87460                    /1/30Wx30H/2301054045
# 87461                    /2/30Wx30H/2301110005
# 87462                    /2/30Wx30H/2301110005
#
#       galleryImages(qualifier)[collection-delimiter=|]
# 0                                          12069560701
# 1                                          12155600511
# 2                                          13119190601
# 3                  15026020341|15026020342|15026020343
# 4                  15026020341|15026020342|15026020343
# ...                                                ...
# 87458                          23010140381|23010140382
# 87459                          23010540451|23010540452
# 87460                          23010540451|23010540452
# 87461                          23011100051|23011100052
# 87462                          23011100051|23011100052
#
# [87463 rows x 10 columns]

# %%
ProductosSAP["sku"] = (ProductosSAP["code[unique=true]"].str[:7]+ProductosSAP["code[unique=true]"].str[8:]).str[:10].astype(str)
ProductosSAP = ProductosSAP.drop_duplicates(subset="sku", keep="first")

df_sap = ProductosSAP[ProductosSAP['picture(code)[collection-delimiter=|]'].isna()]
df_sap.loc[:,'SAP'] = 'SinFoto'
df_sap = df_sap[['sku', 'SAP']]
df_sap.reset_index(drop=True, inplace=True)
df_sap
# Out:
# C:\Users\fcolin\AppData\Local\Temp\ipykernel_18292\1962489260.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sap.loc[:,'SAP'] = 'SinFoto'
#             sku      SAP
# 0    1603986103  SinFoto
# 1    1606956103  SinFoto
# 2    1609803103  SinFoto
# 3    1705262103  SinFoto
# 4    1706658094  SinFoto
# ..          ...      ...
# 439  2211894091  SinFoto
# 440  2211894094  SinFoto
# 441  2211894095  SinFoto
# 442  2211894106  SinFoto
# 443  2218665070  SinFoto
#
# [444 rows x 2 columns]

# %%
ProductosSAP
# Out:
#             INSERT_UPDATE Product code[unique=true]  \
# 0      ApparelStyleVariantProduct       1206956_070
# 1      ApparelStyleVariantProduct       1215560_051
# 2      ApparelStyleVariantProduct       1311919_060
# 3       ApparelSizeVariantProduct    1502602_034203
# 7      ApparelStyleVariantProduct       1502602_070
# ...                           ...               ...
# 86097  ApparelStyleVariantProduct       2300882_065
# 86102  ApparelStyleVariantProduct       2300947_034
# 86104  ApparelStyleVariantProduct       2300947_038
# 86106  ApparelStyleVariantProduct       2300948_047
# 86108  ApparelStyleVariantProduct       2300948_065
#
#                    name[lang=es] picture(code)[collection-delimiter=|]  \
# 0          Máscara pestañas base               /1200Wx1200H/1206956070
# 1           Perfume Only For You          /izq-/1200Wx1200H/1215560051
# 2            Perfume Sunset Love               /1200Wx1200H/1311919060
# 3      Flip flop textura correas          /der-/1200Wx1200H/1502602034
# 7      Flip flop textura correas               /1200Wx1200H/1502602070
# ...                          ...                                   ...
# 86097    Top satinado con encaje             /3/1200Wx1200H/2300882065
# 86102   Llavero mariposa brillos             /2/1200Wx1200H/2300947034
# 86104   Llavero mariposa brillos             /2/1200Wx1200H/2300947038
# 86106   Llavero aguacate corazon             /2/1200Wx1200H/2300948047
# 86108   Llavero aguacate corazon             /2/1200Wx1200H/2300948065
#
#       thumbnail(code)[collection-delimiter=|]  \
# 0                         /96Wx96H/1206956070
# 1                    /izq-/96Wx96H/1215560051
# 2                         /96Wx96H/1311919060
# 3                    /der-/96Wx96H/1502602034
# 7                         /96Wx96H/1502602070
# ...                                       ...
# 86097                   /3/96Wx96H/2300882065
# 86102                   /2/96Wx96H/2300947034
# 86104                   /2/96Wx96H/2300947038
# 86106                   /2/96Wx96H/2300948047
# 86108                   /2/96Wx96H/2300948065
#
#       detail(code)[collection-delimiter=|]  \
# 0                    /300Wx300H/1206956070
# 1               /izq-/300Wx300H/1215560051
# 2                    /300Wx300H/1311919060
# 3               /der-/300Wx300H/1502602034
# 7                    /300Wx300H/1502602070
# ...                                    ...
# 86097              /3/300Wx300H/2300882065
# 86102              /2/300Wx300H/2300947034
# 86104              /2/300Wx300H/2300947038
# 86106              /2/300Wx300H/2300948047
# 86108              /2/300Wx300H/2300948065
#
#                     normal(code)[collection-delimiter=|]  \
# 0                /30Wx30H/1206956070|/65Wx65H/1206956070
# 1      /izq-/30Wx30H/1215560051|/izq-/65Wx65H/1215560051
# 2                /30Wx30H/1311919060|/65Wx65H/1311919060
# 3      /der-/30Wx30H/1502602034|/der-/65Wx65H/1502602034
# 7                /30Wx30H/1502602070|/65Wx65H/1502602070
# ...                                                  ...
# 86097                              /3/65Wx65H/2300882065
# 86102                              /2/65Wx65H/2300947034
# 86104                              /2/65Wx65H/2300947038
# 86106                              /2/65Wx65H/2300948047
# 86108                              /2/65Wx65H/2300948065
#
#       others(code)[collection-delimiter=|]  \
# 0                    /515Wx515H/1206956070
# 1               /izq-/515Wx515H/1215560051
# 2                    /515Wx515H/1311919060
# 3               /der-/515Wx515H/1502602034
# 7                    /515Wx515H/1502602070
# ...                                    ...
# 86097              /3/515Wx515H/2300882065
# 86102              /2/515Wx515H/2300947034
# 86104              /2/515Wx515H/2300947038
# 86106              /2/515Wx515H/2300948047
# 86108              /2/515Wx515H/2300948065
#
#       thumbnails(code)[collection-delimiter=|]  \
# 0                          /30Wx30H/1206956070
# 1                     /izq-/30Wx30H/1215560051
# 2                          /30Wx30H/1311919060
# 3                     /der-/30Wx30H/1502602034
# 7                          /30Wx30H/1502602070
# ...                                        ...
# 86097                    /3/30Wx30H/2300882065
# 86102                    /2/30Wx30H/2300947034
# 86104                    /2/30Wx30H/2300947038
# 86106                    /2/30Wx30H/2300948047
# 86108                    /2/30Wx30H/2300948065
#
#       galleryImages(qualifier)[collection-delimiter=|]         sku
# 0                                          12069560701  1206956070
# 1                                          12155600511  1215560051
# 2                                          13119190601  1311919060
# 3                  15026020341|15026020342|15026020343  1502602034
# 7                                          15026020701  1502602070
# ...                                                ...         ...
# 86097  23008820651|23008820652|23008820653|23008820654  2300882065
# 86102                          23009470341|23009470342  2300947034
# 86104                          23009470381|23009470382  2300947038
# 86106                          23009480471|23009480472  2300948047
# 86108                          23009480651|23009480652  2300948065
#
# [26904 rows x 11 columns]

# %%
# INVENTARIOS --------------------------------------------------------------------------------------------
print("Leyendo base de datos... extrayendo tallas")
from sqlalchemy.engine import URL
from sqlalchemy import create_engine
import json

with open(path_contrasenas) as f:
    credenciales = json.load(f)

try: 
    connection_string = 'DRIVER={SQL Server};SERVER=Shjet-prod;DATABASE=Allocations;UID='+ credenciales['usuario'] +';PWD='+credenciales['password']
    connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connection_string})
    engine = create_engine(connection_url)
    conn = engine.connect()
except:
    print("Base de datos en mantenimiento")
    exit()
    
query = '''
SELECT  CONCAT([Item No_] ,[Cod_Color]) AS sku
     ,[Division Code]
     ,[Status Code] 
     ,SUM([Inv_E002]) AS [Inv_E002]
     ,SUM([Inv_TransE002]) AS [Inv_TransE002]
     ,SUM([ODS]) AS [ODS] 
     ,SUM([Qtty Pen]) AS [Qtty Pen]
       
  FROM [Flash_BC].[dbo].[PP_Shasacom]
  WHERE [Color] IS NOT NULL 
  AND [Item Category Code] != 'CANDY'
  GROUP BY CONCAT([Item No_] ,[Cod_Color])
     ,[Division Code]
      ,[Item Category Code]
      ,[Product Group Code]
      ,[Oferta]
      ,[Status Code]  
 '''
df_query = pd.read_sql_query(query, conn)
# sustituir los valores nulos por 0
df_query['Qtty Pen'].fillna(0, inplace=True)
# las qtty pen de joyeria deben ser 0 si el status es VAN
df_query.loc[(df_query['Qtty Pen']>0) & (df_query["Division Code"] == "M-JEW")& (df_query["Status Code"] == "VAN"), 'Qtty Pen'] = 0
df_query.loc[(df_query['Qtty Pen']>0) & (df_query["Division Code"] == "W-JEW")& (df_query["Status Code"] == "VAN"), 'Qtty Pen'] = 0
df_query = df_query[['sku', 'Inv_E002', 'Inv_TransE002','ODS', 'Qtty Pen']]
df_query.index = df_query['sku']
df_query.drop('sku', axis=1, inplace=True)
# substitute nan values with 0
df_query.fillna(0, inplace=True)
# substitute negative values with 0
df_query[df_query < 0] = 0
# Sumando todas las columnas
df_query['Total'] = df_query.sum(axis=1)
# Seleccionando solo los productos con un total mayor a 0 
df_query = df_query[df_query['Total']>0]
df_query.reset_index(inplace=True)
df_query
# Out:
# Leyendo base de datos... extrayendo tallas
#               sku  Inv_E002  Inv_TransE002  ODS  Qtty Pen  Total
# 0      1206956070       2.0            0.0  0.0       0.0    2.0
# 1      1606956030       5.0            0.0  0.0       0.0    5.0
# 2      1610676070      16.0            0.0  0.0       0.0   16.0
# 3      1610833006      34.0            0.0  0.0       0.0   34.0
# 4      1709991094      11.0            0.0  0.0       0.0   11.0
# ...           ...       ...            ...  ...       ...    ...
# 16761  2301352063       8.0            0.0  0.0       0.0    8.0
# 16762  2301358013       8.0            0.0  0.0       0.0    8.0
# 16763  2301380015       0.0           12.0  0.0       0.0   12.0
# 16764  2301381012       0.0            6.0  0.0       0.0    6.0
# 16765  2301525070       0.0            9.0  0.0       0.0    9.0
#
# [16766 rows x 6 columns]

# %%
df = pd.merge(df_sap, df_query, on="sku", how="left")
df['Total'].fillna(0, inplace=True)
df['Total'] = df['Total'].astype(int)
df = df[df['Total']>0]
df = pd.merge(df, drive, on="sku", how="left")
df
# Out:
#            sku      SAP  Inv_E002  Inv_TransE002  ODS  Qtty Pen  Total  \
# 0   1807473070  SinFoto       6.0            0.0  0.0       0.0      6
# 1   2202158003  SinFoto       6.0            0.0  0.0       0.0      6
# 2   2202231016  SinFoto       1.0            0.0  0.0       0.0      1
# 3   2202233049  SinFoto       1.0            0.0  0.0       0.0      1
# 4   2202403092  SinFoto       3.0            0.0  0.0       0.0      3
# 5   2202826058  SinFoto       1.0            0.0  0.0       0.0      1
# 6   2203097032  SinFoto       1.0            0.0  0.0       0.0      1
# 7   2203122106  SinFoto       8.0            0.0  0.0       0.0      8
# 8   2204273070  SinFoto       6.0            0.0  0.0       0.0      6
# 9   2204915094  SinFoto       1.0            0.0  0.0       0.0      1
# 10  2205177093  SinFoto       2.0            0.0  0.0       0.0      2
# 11  2205246070  SinFoto       1.0            0.0  0.0       0.0      1
# 12  2205897102  SinFoto       1.0            0.0  0.0       0.0      1
# 13  2206149028  SinFoto       1.0            0.0  0.0       0.0      1
# 14  2218665070  SinFoto       8.0            0.0  0.0       0.0      8
#
#                                                  path
# 0                                       \Calzado 2019
# 1   \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 2                                 \Editadas 2021\Ropa
# 3                                 \Editadas 2021\Ropa
# 4   \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 5   \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 6   \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 7   \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 8                       \Historico todos los tamaños
# 9   \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 10  \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 11  \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 12  \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 13  \CONNECT HISTORICO\DEFINITIVS CONNECT\DEFINITI...
# 14                                                NaN
